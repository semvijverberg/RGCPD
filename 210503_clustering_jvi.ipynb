# %% [markdown]
# # Clustering

# %%
# %load_ext autoreload
# %autoreload 2
import os, inspect, sys
import cartopy.crs as ccrs
main_dir = os.path.join(
    os.path.dirname(
    os.path.dirname(
        os.path.abspath(inspect.getfile(inspect.currentframe())))),'RGCPD') # RGCPD folder directory
thesis_dir = os.path.dirname(main_dir)
data_dir = os.path.join(thesis_dir, 'Data')
RGCPD_func = os.path.join(main_dir, 'RGCPD')
cluster_func = os.path.join(main_dir, 'clustering')
if RGCPD_func not in sys.path:
    sys.path.append(RGCPD_func)
    sys.path.append(cluster_func)

# %%
# %load_ext autoreload
# %autoreload 2
import clustering_spatial as cl
from RGCPD import RGCPD
import plot_maps

#preprocessed target variable and precursors, with extent set to Europe and masked to sea/land. PRODUCES WEIRD CLUSTERING
TV_prec_list_pp = [('t2m', 
                 os.path.join(thesis_dir, 'Data', 't2m_1950-2020_1-12_monthly_0.25deg_Europe.nc')),
                ('sst',
                 os.path.join(thesis_dir, 'Data', 'sst_1950-2020_1_12_monthly_1.0deg_Europe.nc')),
                ('swvl1_2',
                os.path.join(thesis_dir, 'Data', 'swvl_1950-2020_1_12_monthly_1.0deg_Europe.nc'))
               ]

#define input: original, global datasets, non-masked, except for svwl = masked and summed for layers 1 and 2
TV_prec_list_org = [('fake', os.path.join(thesis_dir, 'Data', 't2m_1950-2020_1-12_monthly_0.25deg.nc')),
                ('value',
                 os.path.join(thesis_dir, 'Data', 'sst_1950-2020_1_12_monthly_1.0deg.nc')),
                ('value',
                os.path.join(thesis_dir, 'Data', 'swvl1_2_1950-2020_1_12_monthly_1.0deg_mask.nc'))
               ]

#set start and end date for target variable
start_end_TVdate = ('01-01', '12-31')

rg = RGCPD(list_of_name_path = TV_prec_list_org, start_end_TVdate = start_end_TVdate)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
rg.pp_precursors()
# Out:
# Loaded pre-processed data of value
#
# Loaded pre-processed data of value

# %%
rg.list_precur_pp
# Out:
# [('value',
#   'C:\\Users\\Van Ingen\\Documents\\Jannes\\School\\VU\\Econometrics\\Thesis\\Data\\preprocessed\\sst_1950-2020_jan_dec_monthly_1.0deg.nc'),
#  ('value',
#   'C:\\Users\\Van Ingen\\Documents\\Jannes\\School\\VU\\Econometrics\\Thesis\\Data\\preprocessed\\swvl1_2_1950-2020_jan_dec_monthly_1.0deg_mask.nc')]

# %%
#cluster all precursors with some q to n clusters and show clustering maps, HIERARCHICAL CLUSTERING
mask = [-25.0,40.0,32.0,72.0]
mask_arr = os.path.join(data_dir,'Europe_mask.nc')
q = 95
n_clusters = [3, 4, 5, 6, 7]
projection = ccrs.LambertCylindrical(central_longitude = 0)

for i in rg.list_precur_pp:
    var_filename = i[1]
    xrclustered, results = cl.dendogram_clustering(var_filename, mask = mask_arr,
                                                   kwrgs_clust={'q':q, 'n_clusters':n_clusters})
    fig = plot_maps.plot_labels(xrclustered, {'col_dim':'n_clusters', 'title':'Hierarchical Clustering', 'map_proj': projection,
                                             'zoomregion':(-30.0,45.0,32.0,75.0)})
# Out:
# sorting longitude
# clustering fake: 0, n_clusters: 3
# clustering fake: 0, n_clusters: 4
# clustering fake: 0, n_clusters: 5
# clustering fake: 0, n_clusters: 6
# clustering fake: 0, n_clusters: 7
#
#
# Plotting Corr maps sst, split 0, n_clusters 3
# Plotting Corr maps sst, split 0, n_clusters 4
# Plotting Corr maps sst, split 0, n_clusters 5
# Plotting Corr maps sst, split 0, n_clusters 6
# Plotting Corr maps sst, split 0, n_clusters 7
# sorting longitude
# clustering fake: 0, n_clusters: 3
# clustering fake: 0, n_clusters: 4
# clustering fake: 0, n_clusters: 5
# clustering fake: 0, n_clusters: 6
# clustering fake: 0, n_clusters: 7
#
#
# Plotting Corr maps swvl1_2, split 0, n_clusters 3
# Plotting Corr maps swvl1_2, split 0, n_clusters 4
# Plotting Corr maps swvl1_2, split 0, n_clusters 5
# Plotting Corr maps swvl1_2, split 0, n_clusters 6
# Plotting Corr maps swvl1_2, split 0, n_clusters 7

# %%
#cluster all precursors using some distance eps and show clustering maps, DBSCAN CLUSTERING
eps = [5,10]
projection = ccrs.LambertCylindrical(central_longitude=0)

for i in rg.list_precur_pp:
    var_filename = i[1]
    xrclustered, results = cl.sklearn_clustering(var_filename, mask=mask_arr, clustermethodkey='DBSCAN', kwrgs_clust={'eps':eps})
    xrclustered += 1
    print(xrclustered)
    fig = plot_maps.plot_labels(xrclustered, {'col_dim':'eps', 'title':'Density-Based Spatial Clustering of Applications with Noise', 
                                              'map_proj': projection,
                                             'zoomregion':(-30.0,45.0,32.0,75.0)})
# Out:
# sorting longitude
# clustering fake: 0, eps: 5 [[-3.27670000e+04 -3.27670000e+04 -3.27670000e+04 ... -3.27670000e+04
#   -3.27670000e+04 -3.27670000e+04]
#  [-3.27670000e+04 -3.27670000e+04 -3.27670000e+04 ... -3.27670000e+04
#   -3.27670000e+04 -3.27670000e+04]
#  [-3.27670000e+04 -3.27670000e+04 -3.27670000e+04 ... -3.27670000e+04
#   -3.27670000e+04 -3.27670000e+04]
#  ...
#  [ 2.18431637e+00  5.31625024e-01  1.86113887e+00 ... -8.28263738e-01
#   -6.19223862e-01  2.35905111e-03]
#  [ 2.50021543e+00  2.69975860e-01  1.96929404e+00 ... -3.84169270e-01
#   -7.84835783e-01 -2.72881694e-01]
#  [ 1.80341269e+00  9.30788904e-02  1.90834328e+00 ... -1.10282265e-01
#   -2.79483799e-01  1.29329033e-01]]
# clustering fake: 0, eps: 10 [[-3.27670000e+04 -3.27670000e+04 -3.27670000e+04 ... -3.27670000e+04
#   -3.27670000e+04 -3.27670000e+04]
#  [-3.27670000e+04 -3.27670000e+04 -3.27670000e+04 ... -3.27670000e+04
#   -3.27670000e+04 -3.27670000e+04]
#  [-3.27670000e+04 -3.27670000e+04 -3.27670000e+04 ... -3.27670000e+04
#   -3.27670000e+04 -3.27670000e+04]
#  ...
#  [ 2.18431637e+00  5.31625024e-01  1.86113887e+00 ... -8.28263738e-01
#   -6.19223862e-01  2.35905111e-03]
#  [ 2.50021543e+00  2.69975860e-01  1.96929404e+00 ... -3.84169270e-01
#   -7.84835783e-01 -2.72881694e-01]
#  [ 1.80341269e+00  9.30788904e-02  1.90834328e+00 ... -1.10282265e-01
#   -2.79483799e-01  1.29329033e-01]]
# <xarray.DataArray 'sst' (eps: 2, latitude: 180, longitude: 360)>
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]])
# Coordinates:
#   * eps        (eps) int32 5 10
#   * longitude  (longitude) float64 0.5 1.5 2.5 3.5 ... 356.5 357.5 358.5 359.5
#   * latitude   (latitude) float64 -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#     mask       (latitude, longitude) bool ...
# Attributes:
#     long_name:     Sea surface temperature
#     units:         K
#     is_DataArray:  1
#     anomaly:       True
#     fft:           True
#     n_harmonics:   6
#     detrend:       True
#     method:        DBSCAN
#     kwrgs:         {'eps': [5, 10]}
#     target:        sst
#     hash:          ad06c
# Plotting Corr maps sst, split 0, eps 5
# Plotting Corr maps sst, split 0, eps 10
# sorting longitude
# clustering fake: 0, eps: 5 [[ 1.14139333e-01 -1.98720994e-02 -4.94052980e-02 ... -8.41061599e-02
#   -9.10605136e-02  1.90453993e-02]
#  [-3.27670000e+04 -3.27670000e+04 -3.27670000e+04 ... -3.27670000e+04
#   -3.27670000e+04 -3.27670000e+04]
#  [ 8.95347985e-02 -4.10435182e-02 -5.96590267e-02 ... -8.91356330e-02
#   -7.85317131e-02 -8.00722981e-02]
#  ...
#  [-3.27670000e+04 -3.27670000e+04 -3.27670000e+04 ... -3.27670000e+04
#   -3.27670000e+04 -3.27670000e+04]
#  [-3.27670000e+04 -3.27670000e+04 -3.27670000e+04 ... -3.27670000e+04
#   -3.27670000e+04 -3.27670000e+04]
#  [-3.27670000e+04 -3.27670000e+04 -3.27670000e+04 ... -3.27670000e+04
#   -3.27670000e+04 -3.27670000e+04]]
# clustering fake: 0, eps: 10 [[ 1.14139333e-01 -1.98720994e-02 -4.94052980e-02 ... -8.41061599e-02
#   -9.10605136e-02  1.90453993e-02]
#  [-3.27670000e+04 -3.27670000e+04 -3.27670000e+04 ... -3.27670000e+04
#   -3.27670000e+04 -3.27670000e+04]
#  [ 8.95347985e-02 -4.10435182e-02 -5.96590267e-02 ... -8.91356330e-02
#   -7.85317131e-02 -8.00722981e-02]
#  ...
#  [-3.27670000e+04 -3.27670000e+04 -3.27670000e+04 ... -3.27670000e+04
#   -3.27670000e+04 -3.27670000e+04]
#  [-3.27670000e+04 -3.27670000e+04 -3.27670000e+04 ... -3.27670000e+04
#   -3.27670000e+04 -3.27670000e+04]
#  [-3.27670000e+04 -3.27670000e+04 -3.27670000e+04 ... -3.27670000e+04
#   -3.27670000e+04 -3.27670000e+04]]
# <xarray.DataArray 'swvl1_2' (eps: 2, latitude: 180, longitude: 360)>
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]])
# Coordinates:
#   * eps        (eps) int32 5 10
#   * longitude  (longitude) float64 0.5 1.5 2.5 3.5 ... 356.5 357.5 358.5 359.5
#   * latitude   (latitude) float64 -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#     mask       (latitude, longitude) bool ...
# Attributes:
#     long_name:     Volumetric soil water layer 1
#     units:         m**3 m**-3
#     is_DataArray:  1
#     anomaly:       True
#     fft:           True
#     n_harmonics:   6
#     detrend:       True
#     method:        DBSCAN
#     kwrgs:         {'eps': [5, 10]}
#     target:        swvl1_2
#     hash:          f8764
# Plotting Corr maps swvl1_2, split 0, eps 5
# Plotting Corr maps swvl1_2, split 0, eps 10

# %%
#what are we doing here?
for i in rg.list_precur_pp:
    var_filename = i[1]

    xrclustered, results = cl.sklearn_clustering(var_filename, mask=mask, kwrgs_load={'tfreq':15,
                                                                                      'start_end_date':('06-01','08-31')},
                                                 clustermethodkey='DBSCAN', kwrgs_clust={'eps':[8, 10]})
    xrclustered += 1
    fig = plot_maps.plot_labels(xrclustered, {'col_dim':'eps', 
                                              'title':'Density-Based Spatial Clustering of Applications with Noise (JJA, 15-day means)'
                                             }
                               )
# Out:
# sorting longitude
# clustering fake: 0, eps: 8
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-4ff0de1f3dca> in <module>
#       5     xrclustered, results = cl.sklearn_clustering(var_filename, mask=mask, kwrgs_load={'tfreq':15,
#       6                                                                                       'start_end_date':('06-01','08-31')},
# ----> 7                                                  clustermethodkey='DBSCAN', kwrgs_clust={'eps':[8, 10]})
#       8     xrclustered += 1
#       9     fig = plot_maps.plot_labels(xrclustered, {'col_dim':'eps',
#
# ~\Documents\Jannes\School\VU\Econometrics\Thesis\RGCPD\clustering\clustering_spatial.py in sklearn_clustering(var_filename, mask, kwrgs_load, clustermethodkey, kwrgs_clust)
#     122                 kwrgs_l = adjust_kwrgs(kwrgs_load.copy(), new_coords, v1, v2)
#     123                 print(f"\rclustering {new_coords[0]}: {v1}, {new_coords[1]}: {v2} ", end="")
# --> 124                 xarray = functions_pp.import_ds_timemeanbins(var_filename, **kwrgs_l)
#     125
#     126
#
# ~\Documents\Jannes\School\VU\Econometrics\Thesis\RGCPD\RGCPD\functions_pp.py in import_ds_timemeanbins(filepath, tfreq, start_end_date, start_end_year, closed, start_end_TVdate, selbox, loadleap, to_xarr, seldates, dailytomonths, format_lon)
#     346                             start_end_year,
#     347                             closed=closed,
# --> 348                             start_end_TVdate=start_end_TVdate)[0]
#     349     ds = ds.squeeze()
#     350     # check if no axis has length 0:
#
# ~\Documents\Jannes\School\VU\Econometrics\Thesis\RGCPD\RGCPD\functions_pp.py in time_mean_bins(xr_or_df, tfreq, start_end_date, start_end_year, closed, start_end_TVdate, verbosity)
#     435         x = bins[-1]+1 + x
#     436         bins = np.insert(bins, bins.size, x)
# --> 437     label_bins = xr.DataArray(bins, [xarray.coords['time'][:]], name='time')
#     438     label_dates = xr.DataArray(xarray.time.values, [xarray.coords['time'][:]], name='time')
#     439     xarray['bins'] = label_bins
#
# C:\miniconda\envs\RGCPD1\lib\site-packages\xarray\core\dataarray.py in __init__(self, data, coords, dims, name, attrs, indexes, fastpath)
#     407             data = _check_data_shape(data, coords, dims)
#     408             data = as_compatible_data(data)
# --> 409             coords, dims = _infer_coords_and_dims(data.shape, coords, dims)
#     410             variable = Variable(dims, data, attrs, fastpath=True)
#     411             indexes = dict(
#
# C:\miniconda\envs\RGCPD1\lib\site-packages\xarray\core\dataarray.py in _infer_coords_and_dims(shape, coords, dims)
#     158                     "conflicting sizes for dimension %r: "
#     159                     "length %s on the data but length %s on "
# --> 160                     "coordinate %r" % (d, sizes[d], s, k)
#     161                 )
#     162
#
# ValueError: conflicting sizes for dimension 'time': length 1065 on the data but length 71 on coordinate 'time'
